# %%
import matplotlib.pyplot as axes
import numpy as np
from matplotlib.pyplot import figure
import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib
from matplotlib.pyplot import figure, xticks

import matplotlib.pyplot as plt

plt.style.use('ggplot')
# plt.rcParams['axes.facecolor'] = 'white'
pd.set_option('display.max_colwidth', None)

from icecream import ic

# %%
df_1 = pd.read_csv(r"./adv-training/seed24032022-dfcomb.csv")
df_2 = pd.read_csv(r"./adv-training/seed42-dfcomb.csv")
df_3 = pd.read_csv(r"./adv-training/seed26092020-dfcomb.csv")


df_comb = (pd.concat([df_1, df_2, df_3]).groupby(
    'filename', as_index=False).agg({
        'model_target':'first', 
        'downstream_task':'first',
        'perturbation_technique':'first',
        'codemix_lang':'first',
        'perturb_ratio':'first',
        'before_attack_acc':['mean', 'std'],
        'after_attack_acc':['mean', 'std'],
        'delta_acc':['mean', 'std'],
        'avg_semantic_sim':['mean', 'std'],
        'adv_training':['mean', 'std'],
        'acc_improvement_on_adv_train':['mean', 'std'],
        'acc_adv_training_on_orig':['mean', 'std'],
        'orig_acc_vs_adv':['mean', 'std'],
        'avg_running_time(s)':'mean',

        }
    )
)
# df_comb.to_csv("a.csv")

df_comb.to_csv("./result-analysis/dfcomb_adv_train.csv", index=False)

# %%
d_task = 'emotion'


emot_df1_dfcomb = df_1.loc[[df_1[(df_1['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
emot_df1_dfcomb['seed'] = 24032022
emot_df1_dfcomb['task'] = d_task
emot_df1_dfcomb = emot_df1_dfcomb[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(emot_df1_dfcomb)

d_task = 'sentiment'


sent_df1_dfcomb = df_1.loc[[df_1[(df_1['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
sent_df1_dfcomb['seed'] = 24032022
sent_df1_dfcomb['task'] = d_task
sent_df1_dfcomb = sent_df1_dfcomb[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(sent_df1_dfcomb)
# Out:
#                                         filename     task  before_attack_acc  \
# 251  xlmrlarge-emotion-codemixing-su-adv-0.8.csv  emotion           0.777273
#
#      after_attack_acc  adv_training  acc_adv_training_on_orig  best_epoch  \
# 251          0.634091      0.704545                  0.802273         3.0
#
#          seed
# 251  24032022
#                                           filename       task  \
# 257  xlmrlarge-sentiment-codemixing-fr-adv-0.4.csv  sentiment
#
#      before_attack_acc  after_attack_acc  adv_training  \
# 257              0.934             0.902         0.952
#
#      acc_adv_training_on_orig  best_epoch      seed
# 257                     0.962         1.0  24032022

# %%
d_task = 'emotion'


emot_df2_dfcomb = df_2.loc[[df_2[(df_2['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
emot_df2_dfcomb['seed'] = 42
emot_df2_dfcomb['task'] = d_task
emot_df2_dfcomb = emot_df2_dfcomb[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(emot_df2_dfcomb)

d_task = 'sentiment'


sent_df2_dfcomb = df_2.loc[[df_2[(df_2['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
sent_df2_dfcomb['seed'] = 42
sent_df2_dfcomb['task'] = d_task
sent_df2_dfcomb = sent_df2_dfcomb[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(sent_df2_dfcomb)
# Out:
#                              filename     task  before_attack_acc  \
# 235  xlmrlarge-emotion-sr-adv-0.8.csv  emotion           0.788636
#
#      after_attack_acc  adv_training  acc_adv_training_on_orig  best_epoch  \
# 235          0.572727      0.636364                  0.797727         4.0
#
#      seed
# 235    42
#                                           filename       task  \
# 278  xlmrlarge-sentiment-codemixing-su-adv-0.6.csv  sentiment
#
#      before_attack_acc  after_attack_acc  adv_training  \
# 278              0.948             0.906          0.95
#
#      acc_adv_training_on_orig  best_epoch  seed
# 278                     0.972         0.0    42

# %%
d_task = 'emotion'


emot_df3_dfcomb = df_3.loc[[df_3[(df_3['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
emot_df3_dfcomb['seed'] = 26092020
emot_df3_dfcomb['task'] = d_task
emot_df3_dfcomb = emot_df3_dfcomb[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(emot_df3_dfcomb)

d_task = 'sentiment'


sent_df3_dfcomb = df_3.loc[[df_3[(df_3['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
sent_df3_dfcomb['seed'] = 26092020
sent_df3_dfcomb['task'] = d_task
sent_df3_dfcomb = sent_df3_dfcomb[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(sent_df3_dfcomb)
# Out:
#                                         filename     task  before_attack_acc  \
# 226  xlmrlarge-emotion-codemixing-en-adv-0.6.csv  emotion           0.781818
#
#      after_attack_acc  adv_training  acc_adv_training_on_orig  best_epoch  \
# 226          0.665909      0.722727                       0.8         3.0
#
#          seed
# 226  26092020
#                                           filename       task  \
# 265  xlmrlarge-sentiment-codemixing-it-adv-0.4.csv  sentiment
#
#      before_attack_acc  after_attack_acc  adv_training  \
# 265               0.94             0.908         0.942
#
#      acc_adv_training_on_orig  best_epoch      seed
# 265                     0.966         1.0  26092020

# %%
compiled_1 = pd.concat([
    emot_df1_dfcomb, 
    emot_df2_dfcomb, 
    emot_df3_dfcomb,
    sent_df1_dfcomb, 
    sent_df2_dfcomb, 
    sent_df3_dfcomb
    ], axis=0).reset_index()
compiled_1['finetuning_method'] = 'dfcomb'
compiled_1
# Out:
#    index                                       filename       task  \
# 0    251    xlmrlarge-emotion-codemixing-su-adv-0.8.csv    emotion
# 1    235               xlmrlarge-emotion-sr-adv-0.8.csv    emotion
# 2    226    xlmrlarge-emotion-codemixing-en-adv-0.6.csv    emotion
# 3    257  xlmrlarge-sentiment-codemixing-fr-adv-0.4.csv  sentiment
# 4    278  xlmrlarge-sentiment-codemixing-su-adv-0.6.csv  sentiment
# 5    265  xlmrlarge-sentiment-codemixing-it-adv-0.4.csv  sentiment
#
#    before_attack_acc  after_attack_acc  adv_training  \
# 0           0.777273          0.634091      0.704545
# 1           0.788636          0.572727      0.636364
# 2           0.781818          0.665909      0.722727
# 3           0.934000          0.902000      0.952000
# 4           0.948000          0.906000      0.950000
# 5           0.940000          0.908000      0.942000
#
#    acc_adv_training_on_orig  best_epoch      seed finetuning_method
# ...

# %%
df_1 = pd.read_csv(r"./adv-training/seed24032022-perturb_data_only.csv")
df_2 = pd.read_csv(r"./adv-training/seed42-perturb_data_only.csv")
df_3 = pd.read_csv(r"./adv-training/seed26092020-perturb_data_only.csv")


df_comb = (pd.concat([df_1, df_2, df_3]).groupby(
    'filename', as_index=False).agg({
        'model_target':'first', 
        'downstream_task':'first',
        'perturbation_technique':'first',
        'codemix_lang':'first',
        'perturb_ratio':'first',
        'before_attack_acc':['mean', 'std'],
        'after_attack_acc':['mean', 'std'],
        'delta_acc':['mean', 'std'],
        'avg_semantic_sim':['mean', 'std'],
        'adv_training':['mean', 'std'],
        'acc_improvement_on_adv_train':['mean', 'std'],
        'acc_adv_training_on_orig':['mean', 'std'],
        'orig_acc_vs_adv':['mean', 'std'],
        'avg_running_time(s)':'mean',

        }
    )
)
# df_comb.to_csv("a.csv")

df_comb.to_csv("./result-analysis/perturb_data_only_adv_train.csv", index=False)

# %%
d_task = 'emotion'


emot_df1_perturb_data_only = df_1.loc[[df_1[(df_1['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
emot_df1_perturb_data_only['seed'] = 24032022
emot_df1_perturb_data_only['task'] = d_task
emot_df1_perturb_data_only = emot_df1_perturb_data_only[['filename','task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(emot_df1_perturb_data_only)

d_task = 'sentiment'

sent_df1_perturb_data_only = df_1.loc[[df_1[(df_1['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
sent_df1_perturb_data_only['seed'] = 24032022
sent_df1_perturb_data_only['task'] = d_task
sent_df1_perturb_data_only = sent_df1_perturb_data_only[['filename','task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(sent_df1_perturb_data_only)
# Out:
#                                         filename     task  before_attack_acc  \
# 228  xlmrlarge-emotion-codemixing-fr-adv-0.2.csv  emotion           0.777273
#
#      after_attack_acc  adv_training  acc_adv_training_on_orig  best_epoch  \
# 228          0.645455      0.722727                  0.790909         4.0
#
#          seed
# 228  24032022
#                                   filename       task  before_attack_acc  \
# 93  indobertlarge-sentiment-sr-adv-0.4.csv  sentiment              0.936
#
#     after_attack_acc  adv_training  acc_adv_training_on_orig  best_epoch  \
# 93             0.892         0.934                     0.948         1.0
#
#         seed
# 93  24032022

# %%
d_task = 'emotion'


emot_df2_perturb_data_only = df_2.loc[[df_2[(df_2['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
emot_df2_perturb_data_only['seed'] = 42
emot_df2_perturb_data_only['task'] = d_task
emot_df2_perturb_data_only = emot_df2_perturb_data_only[['filename','task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(emot_df2_perturb_data_only)

d_task = 'sentiment'


sent_df2_perturb_data_only = df_2.loc[[df_2[(df_2['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
sent_df2_perturb_data_only['seed'] = 42
sent_df2_perturb_data_only['task'] = d_task
sent_df2_perturb_data_only = sent_df2_perturb_data_only[['filename','task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(sent_df2_perturb_data_only)
# Out:
#                                         filename     task  before_attack_acc  \
# 225  xlmrlarge-emotion-codemixing-en-adv-0.4.csv  emotion           0.788636
#
#      after_attack_acc  adv_training  acc_adv_training_on_orig  best_epoch  \
# 225          0.663636      0.711364                  0.788636         2.0
#
#      seed
# 225    42
#                                           filename       task  \
# 269  xlmrlarge-sentiment-codemixing-jw-adv-0.4.csv  sentiment
#
#      before_attack_acc  after_attack_acc  adv_training  \
# 269              0.948             0.922         0.968
#
#      acc_adv_training_on_orig  best_epoch  seed
# 269                     0.964         2.0    42

# %%
d_task = 'emotion'


emot_df3_perturb_data_only = df_3.loc[[df_3[(df_3['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
emot_df3_perturb_data_only['seed'] = 26092020
emot_df3_perturb_data_only['task'] = d_task
emot_df3_perturb_data_only = emot_df3_perturb_data_only[['filename','task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(emot_df3_perturb_data_only)

d_task = 'sentiment'


sent_df3_perturb_data_only = df_3.loc[[df_3[(df_3['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
sent_df3_perturb_data_only['seed'] = 26092020
sent_df3_perturb_data_only['task'] = d_task
sent_df3_perturb_data_only = sent_df3_perturb_data_only[['filename','task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
display(sent_df3_perturb_data_only)
# Out:
#                              filename     task  before_attack_acc  \
# 232  xlmrlarge-emotion-sr-adv-0.2.csv  emotion           0.781818
#
#      after_attack_acc  adv_training  acc_adv_training_on_orig  best_epoch  \
# 232          0.629545      0.697727                  0.786364         1.0
#
#          seed
# 232  26092020
#                                           filename       task  \
# 259  xlmrlarge-sentiment-codemixing-fr-adv-0.8.csv  sentiment
#
#      before_attack_acc  after_attack_acc  adv_training  \
# 259               0.94             0.884         0.944
#
#      acc_adv_training_on_orig  best_epoch      seed
# 259                     0.958         2.0  26092020

# %%
compiled_2 = pd.concat([
    emot_df1_perturb_data_only, 
    emot_df2_perturb_data_only, 
    emot_df3_perturb_data_only,
    sent_df1_perturb_data_only, 
    sent_df2_perturb_data_only, 
    sent_df3_perturb_data_only
    ], axis=0).reset_index()
compiled_2['finetuning_method'] = 'perturb_data_only'
compiled_2
# Out:
#    index                                       filename       task  \
# 0    228    xlmrlarge-emotion-codemixing-fr-adv-0.2.csv    emotion
# 1    225    xlmrlarge-emotion-codemixing-en-adv-0.4.csv    emotion
# 2    232               xlmrlarge-emotion-sr-adv-0.2.csv    emotion
# 3     93         indobertlarge-sentiment-sr-adv-0.4.csv  sentiment
# 4    269  xlmrlarge-sentiment-codemixing-jw-adv-0.4.csv  sentiment
# 5    259  xlmrlarge-sentiment-codemixing-fr-adv-0.8.csv  sentiment
#
#    before_attack_acc  after_attack_acc  adv_training  \
# 0           0.777273          0.645455      0.722727
# 1           0.788636          0.663636      0.711364
# 2           0.781818          0.629545      0.697727
# 3           0.936000          0.892000      0.934000
# 4           0.948000          0.922000      0.968000
# 5           0.940000          0.884000      0.944000
#
#    acc_adv_training_on_orig  best_epoch      seed  finetuning_method
# ...

# %%
full_compiled = pd.concat([
    compiled_1,
    compiled_2,
    # compiled_3
    ], axis=0).reset_index()
# compiled_3['finetuning_method'] = '2_step'
full_compiled = full_compiled[['filename', 'task', 'acc_adv_training_on_orig', 'finetuning_method', 'best_epoch', 'seed']]
full_compiled.sort_values(by=['acc_adv_training_on_orig','task'], ascending=False)
# Out:
#                                          filename       task  \
# 4   xlmrlarge-sentiment-codemixing-su-adv-0.6.csv  sentiment
# 5   xlmrlarge-sentiment-codemixing-it-adv-0.4.csv  sentiment
# 10  xlmrlarge-sentiment-codemixing-jw-adv-0.4.csv  sentiment
# 3   xlmrlarge-sentiment-codemixing-fr-adv-0.4.csv  sentiment
# 11  xlmrlarge-sentiment-codemixing-fr-adv-0.8.csv  sentiment
# 9          indobertlarge-sentiment-sr-adv-0.4.csv  sentiment
# 0     xlmrlarge-emotion-codemixing-su-adv-0.8.csv    emotion
# 2     xlmrlarge-emotion-codemixing-en-adv-0.6.csv    emotion
# 1                xlmrlarge-emotion-sr-adv-0.8.csv    emotion
# 6     xlmrlarge-emotion-codemixing-fr-adv-0.2.csv    emotion
# 7     xlmrlarge-emotion-codemixing-en-adv-0.4.csv    emotion
# 8                xlmrlarge-emotion-sr-adv-0.2.csv    emotion
#
#     acc_adv_training_on_orig  finetuning_method  best_epoch      seed
# 4                   0.972000             dfcomb         0.0        42
# ...

# %%
df_1 = pd.read_csv(r"./adv-training/seed24032022-2_step.csv")
df_2 = pd.read_csv(r"./adv-training/seed42-2_step.csv")
df_3 = pd.read_csv(r"./adv-training/seed26092020-2_step.csv")


df_comb = (pd.concat([df_1, df_2, df_3]).groupby(
    'filename', as_index=False).agg({
        'model_target':'first', 
        'downstream_task':'first',
        'perturbation_technique':'first',
        'codemix_lang':'first',
        'perturb_ratio':'first',
        'before_attack_acc':['mean', 'std'],
        'after_attack_acc':['mean', 'std'],
        'delta_acc':['mean', 'std'],
        'avg_semantic_sim':['mean', 'std'],
        'adv_training':['mean', 'std'],
        'acc_improvement_on_adv_train':['mean', 'std'],
        'acc_adv_training_on_orig':['mean', 'std'],
        'orig_acc_vs_adv':['mean', 'std'],
        'avg_running_time(s)':'mean',

        }
    )
)
# df_comb.to_csv("a.csv")

df_comb.to_csv("./result-analysis/2_step_adv_train.csv", index=False)

# %%
# d_task = 'emotion'


# emot_df1_2_step = df_1.loc[[df_1[(df_1['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
# emot_df1_2_step['seed'] = 24032022
# emot_df1_2_step['task'] = d_task
# emot_df1_2_step = emot_df1_2_step[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
# display(emot_df1_2_step)

# d_task = 'sentiment'


# sent_df1_2_step = df_1.loc[[df_1[(df_1['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
# sent_df1_2_step['seed'] = 24032022
# sent_df1_2_step['task'] = d_task
# sent_df1_2_step = sent_df1_2_step[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
# display(sent_df1_2_step)

# %%
# d_task = 'emotion'


# emot_df2_2_step = df_2.loc[[df_2[(df_2['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
# emot_df2_2_step['seed'] = 42
# emot_df2_2_step['task'] = d_task
# emot_df2_2_step = emot_df2_2_step[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
# display(emot_df2_2_step)

# d_task = 'sentiment'


# sent_df2_2_step = df_2.loc[[df_2[(df_2['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
# sent_df2_2_step['seed'] = 42
# sent_df2_2_step['task'] = d_task
# sent_df2_2_step = sent_df2_2_step[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
# display(sent_df2_2_step)

# %%
# d_task = 'emotion'


# emot_df3_2_step = df_3.loc[[df_3[(df_3['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
# emot_df3_2_step['seed'] = 26092020
# emot_df3_2_step['task'] = d_task
# emot_df3_2_step = emot_df3_perturb_data_only[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
# display(emot_df3_2_step)

# d_task = 'sentiment'


# sent_df3_2_step = df_3.loc[[df_3[(df_3['downstream_task'] == d_task)].acc_adv_training_on_orig.idxmax()]]
# sent_df3_2_step['seed'] = 26092020
# sent_df3_2_step['task'] = d_task
# sent_df3_2_step = sent_df3_2_step[['filename', 'task', 'before_attack_acc', 'after_attack_acc', 'adv_training', 'acc_adv_training_on_orig', 'best_epoch', 'seed']]
# display(sent_df3_2_step)

# %%
# compiled_3 = pd.concat([
#     emot_df1_2_step, 
#     emot_df2_2_step, 
#     emot_df3_2_step,
#     sent_df1_2_step, 
#     sent_df2_2_step, 
#     sent_df3_2_step
#     ], axis=0).reset_index()
# compiled_3['finetuning_method'] = '2_step'
# compiled_3

# %%
df_3.head(3)

# %%
df_comb = (pd.concat([df_1, df_2, df_3]).groupby(
    'filename', as_index=False).agg({
        'model_target':'first', 
        'downstream_task':'first',
        'perturbation_technique':'first',
        'codemix_lang':'first',
        'perturb_ratio':'first',
        'before_attack_acc':'mean',
        'after_attack_acc':'mean',
        'delta_acc':'mean',
        'avg_semantic_sim':'mean',
        'adv_training':'mean',
        'acc_improvement_on_adv_train':'mean',
        'acc_adv_training_on_orig':'mean',
        'orig_acc_vs_adv':'mean',
        'avg_running_time(s)':'mean',

        }
    )
)
# df_comb.to_csv("a.csv")

# %%
df_comb.to_csv("./result-analysis/2_step_adv_train.csv", index=False)

# %%
df_comb["model_target"].unique()

# %% [markdown]
# # Plot Accuracy vs Perturbation By Language
#
# 6 Bahasa = 6 Figures
# Tiap figures punya 4 linechart untuk tiap model

# %% [markdown]
# ### Sentiment - English

# %%
# plt.style.use('ggplot')

def visualize_1(lang, task, df=df_comb):   
    lang_map = {
        "en": "English",
        'fr': "French", 
        'id': "Synonym Replaced", 
        'it': "Italian", 
        'jw': "Javanese", 
        'ms': "Malay", 
        'su': "Sundanese"
    }

    color_map = {
        'indobert': "#f5c63c", 
        'indobertlarge': "#f47f68", 
        'xlmrlarge': "#b422c7",
        'mbert': "#1c348c", 
        'xlmr': "#2a9fe8"
    }

    task_map = {
        "emotion": "Emotion Classification",
        "sentiment": "Sentiment Analysis"
    }


    df_lang = df[(df["codemix_lang"] == lang) & (df["downstream_task"] == task)]

    percent_pert = [0, 0.2, 0.4, 0.6, 0.8]
    list_model = df_lang.model_target.unique()
    
    figure(num=None, figsize=(8, 6), dpi=80)


    for model in list_model:
        acc_arr = df_lang[(df_lang["model_target"] == model)].acc_adv_training_on_orig.values
        before_attack_acc_arr = df_lang[(df_lang["model_target"] == model)].before_attack_acc.values[0]
        acc_arr = np.insert(acc_arr, 0, before_attack_acc_arr, axis=0)
        
        # for i, v in enumerate(acc_arr):
        #     plt.annotate(str(format(float(v),".2f")), xy=(percent_pert[i],v), textcoords='offset points', xytext=(5, 5))
        
        if "large" in model:
            plt.plot(percent_pert, acc_arr, '-o', label='{}'.format(model), linestyle='--', color=color_map[model])
        else:
            plt.plot(percent_pert, acc_arr, '-o', label='{}'.format(model), color=color_map[model])
        # plt.plot(percent_pert, acc_arr, '-o', label='{}'.format(model), color=color_map[model])
    
    plt.legend(loc="lower left")
    plt.xlabel('Perturbation Ratio')
    plt.ylabel('Accuracy Score')
    title = 'Indonesian-{} {}'.format(lang_map[lang], task_map[task])
    plt.title(title)
    
    # plt.gca().xaxis.set_major_locator(plt.NullLocator())
    # plt.gca().yaxis.set_major_locator(plt.NullLocator())
    # plt.savefig('plot.png')
    
    plt.savefig('viz/rq1/'+str(task)+'/'+str(title)+'.png',bbox_inches='tight',pad_inches = 0)
    plt.show()

# lang_list = ['en', 'fr', 'id', 'it', 'jw', 'ms', 'su']
# for i in lang_list:
task = "sentiment"
visualize_1("en", task)
visualize_1("fr", task)
visualize_1("id", task)
visualize_1("it", task)
visualize_1("jw", task)
visualize_1("ms", task)
visualize_1("su", task)

# anotasi bisa diganti warnanya sesuai warna linechart
# Kalau judul kepanjangan bisa disingkat pake lang_code

# %%
# plt.style.use('ggplot')

def visualize_2(lang, task, df=df_comb):   
    lang_map = {
        "en": "English",
        'fr': "French", 
        'id': "Synonym Replaced", 
        'it': "Italian", 
        'jw': "Javanese", 
        'ms': "Malay", 
        'su': "Sundanese"
    }

    color_map = {
        'indobert': "#f5c63c", 
        'indobertlarge': "#f47f68", 
        "xlmrlarge": "#b422c7",
        'mbert': "#1c348c", 
        'xlmr': "#2a9fe8"
    }

    task_map = {
        "emotion": "Emotion Classification",
        "sentiment": "Sentiment Analysis"
    }


    df_lang = df[(df["codemix_lang"] == lang) & (df["downstream_task"] == task)]

    percent_pert = [0, 0.2, 0.4, 0.6, 0.8]
    list_model = df_lang.model_target.unique()
    
    figure(num=None, figsize=(8, 6), dpi=80)


    for model in list_model:
        acc_arr = df_lang[(df_lang["model_target"] == model)].after_attack_acc.values
        before_attack_acc_arr = df_lang[(df_lang["model_target"] == model)].before_attack_acc.values[0]
        acc_arr = np.insert(acc_arr, 0, before_attack_acc_arr, axis=0)
        semantic_sim_arr = df_lang[(df_lang["model_target"] == model)].avg_semantic_sim.values
        semantic_sim_arr = np.insert(semantic_sim_arr, 0, 1, axis=0)

        # for i, v in enumerate(acc_arr):
        #     plt.annotate(str(format(float(v),".2f")), xy=(semantic_sim_arr[i],v), textcoords='offset points', xytext=(5, 5))
        
        
        if "large" in model:
            plt.plot(semantic_sim_arr, acc_arr, '-o', label='{}'.format(model), linestyle='--', color=color_map[model])
        else:
            plt.plot(semantic_sim_arr, acc_arr, '-o', label='{}'.format(model), color=color_map[model])
        # plt.plot(semantic_sim_arr, acc_arr, '-o', label='{}'.format(model), color=color_map[model])
    
    plt.legend(loc="lower left")
    plt.xlabel('Semantic Similarity')
    plt.ylabel('Accuracy Score')
    title = 'Indonesian-{} {}'.format(lang_map[lang], task_map[task])
    plt.title(title)
    
    # plt.savefig('plot.png')
    
    plt.savefig('viz/rq2/'+str(task)+'/'+str(title)+'.png',bbox_inches='tight',pad_inches = 0)
    plt.show()

# lang_list = ['en', 'fr', 'id', 'it', 'jw', 'ms', 'su']
# for i in lang_list:
task = "sentiment"
visualize_2("en", task)
visualize_2("fr", task)
visualize_2("id", task)
visualize_2("it", task)
visualize_2("jw", task)
visualize_2("ms", task)
visualize_2("su", task)

# %%
def visualize_3(lang, task, df=df_comb):   
    lang_map = {
        "en": "English",
        'fr': "French", 
        'id': "Synonym Replaced", 
        'it': "Italian", 
        'jw': "Javanese", 
        'ms': "Malay", 
        'su': "Sundanese"
    }

    color_map = {
        'indobert': "#f5c63c", 
        'indobertlarge': "#f47f68", 
        "xlmrlarge": "#b422c7",
        'mbert': "#1c348c", 
        'xlmr': "#2a9fe8"
    }

    task_map = {
        "emotion": "Emotion Classification",
        "sentiment": "Sentiment Analysis"
    }

    # df_lang = df[(df["codemix_lang"] == "en") & (df["downstream_task"] == "emotion")]
    # acc_arr = df_lang[(df_lang["model_target"] == "indobert")].after_attack_acc.values

    df_lang = df[(df["codemix_lang"] == lang) & (df["downstream_task"] == task)]
    # semantic_sim_arr

    percent_pert = [0, 0.2, 0.4, 0.6, 0.8]
    list_model = df_lang.model_target.unique()
    figure(num=None, figsize=(8, 6), dpi=80)


    for model in list_model:
        delta_acc_arr = df_lang[(df_lang["model_target"] == model)].delta_acc.values
        # before_attack_acc_arr = df_lang[(df_lang["model_target"] == model)].before_attack_acc.values[0]
        delta_acc_arr = np.insert(delta_acc_arr, 0, 0, axis=0)
        # semantic_sim_arr = df_lang[(df_lang["model_target"] == model)].avg_semantic_sim.values
        # semantic_sim_arr = np.insert(semantic_sim_arr, 0, 1, axis=0)
        
        # for i, v in enumerate(delta_acc_arr):
        #     plt.annotate(str(format(float(v),".2f")), xy=(percent_pert[i],v), textcoords='offset points', xytext=(5, 5))
        if "large" in model:
            plt.plot(percent_pert, delta_acc_arr, '-o', label='{}'.format(model), linestyle='--', color=color_map[model])
        else:
            plt.plot(percent_pert, delta_acc_arr, '-o', label='{}'.format(model), color=color_map[model])
        
    plt.legend(loc="lower right")
    plt.xlabel('Perturbation Ratio')
    plt.ylabel('Delta Accuracy Score')
    title = 'Indonesian-{} {}'.format(lang_map[lang], task_map[task])
    plt.title(title)
    
    # plt.savefig('plot.png')
    
    plt.savefig('viz/rq3/'+str(task)+'/'+str(title)+'.png',bbox_inches='tight',pad_inches = 0)
    plt.show()

# lang_list = ['en', 'fr', 'id', 'it', 'jw', 'ms', 'su']
# for i in lang_list:
task = "sentiment"
visualize_3("en", task)
visualize_3("fr", task)
visualize_3("id", task)
visualize_3("it", task)
visualize_3("jw", task)
visualize_3("ms", task)
visualize_3("su", task)

# %%
def find_mean_delta(task, df=df_comb):
    # df_lang = df[(df["codemix_lang"] == lang) & (df["downstream_task"] == task)]
    # semantic_sim_arr

    percent_pert = [0, 0.2, 0.4, 0.6, 0.8]
    list_model = df.model_target.unique()
    langs = df.codemix_lang.unique()
    # figure(num=None, figsize=(8, 6), dpi=80)
    # print(lang)
    means = {}
    # print(task)
    for lang in langs:
        df_lang = df[(df["codemix_lang"] == lang) & (df["downstream_task"] == task)]
        print(lang)
        for model in list_model:
            delta_acc_arr = df_lang[(df_lang["model_target"] == model)].delta_acc.values
            # before_attack_acc_arr = df_lang[(df_lang["model_target"] == model)].before_attack_acc.values[0]
            delta_acc_arr = np.insert(delta_acc_arr, 0, 0, axis=0)
            print("{:.2f}".format(np.mean(delta_acc_arr)*100))
            means["model"] = model
            means[lang] = "{:.2f}".format(np.mean(delta_acc_arr)*100)
            # print(means)
        # display(means)
        print()
    return pd.DataFrame([means])

task = "emotion"
find_mean_delta(task)

# %%
def find_mean_semantic(task, df=df_comb):
    percent_pert = [0, 0.2, 0.4, 0.6, 0.8]
    list_model = df.model_target.unique()
    langs = df.codemix_lang.unique()
    # figure(num=None, figsize=(8, 6), dpi=80)
    # print(lang)
    means = {}
    # print(task)
    for lang in langs:
        df_lang = df[(df["codemix_lang"] == lang) & (df["downstream_task"] == task)]
        print(lang)
        for model in list_model:
            semantic_sim_arr = df_lang[(df_lang["model_target"] == model)].avg_semantic_sim.values
            semantic_sim_arr = np.insert(semantic_sim_arr, 0, 1, axis=0)

            print("{:.2f}".format(np.mean(semantic_sim_arr)*100))
            means["model"] = model
            means[lang] = "{:.2f}".format(np.mean(semantic_sim_arr)*100)
            # print(means)
        # display(means)
        print()
    return pd.DataFrame([means])

task = "emotion"
find_mean_semantic(task)

# %%
# 'indobert', 'indobertlarge', 'mbert', 'xlmr', 'xlmrlarge'
# 
task = "sentiment"
model = "mbert"
ratio = 0.2
selected = df_comb[(df_comb["model_target"] == model) & (df_comb["downstream_task"] == task) & (df_comb["perturb_ratio"] == ratio)][["model_target", "codemix_lang", "perturb_ratio", "before_attack_acc", "after_attack_acc", "delta_acc"]]
# df_comb0.765909
selected = selected.sort_values(by=['codemix_lang'])
display(selected)
display(selected.before_attack_acc.values[0])
display(selected.after_attack_acc.values)
display(selected.delta_acc.values)

# %%
emot_perturbed_df_en = pd.read_csv("./data/indobert-emotion-codemixing-en-adv-0.8-valid.csv")
emot_perturbed_df_sr = pd.read_csv("./data/indobert-emotion-sr-adv-0.8-valid.csv")

sent_perturbed_df_en = pd.read_csv("./data/indobert-sentiment-codemixing-en-adv-0.8-valid.csv")
sent_perturbed_df_sr = pd.read_csv("./data/indobert-sentiment-sr-adv-0.8-valid.csv")

# emot_perturbed_df_en.label.unique()
sent_perturbed_df_en.columns

# %%
INDEX2LABEL = {0: 'sadness', 1: 'anger', 2: 'love', 3: 'fear', 4: 'happy'}
df = sent_perturbed_df_en
selected = df[(df["sentiment"] == 0) & (df["pred_label"] == 0) & (df["perturbed_label"] == 1)][["text", "perturbed_text", "pred_proba", 'perturbed_proba', "translated_word(s)", "perturbed_semantic_sim", "sentiment", "pred_label", "perturbed_label"]]

# selected.dropna()
# selected.iloc[2]
selected

# %%
from nltk.tokenize import word_tokenize
from icecream import ic

text = "di sini saya suka makan nasi bakmoy nya . kroket nya juga enak kok . kisaran harga kroket nya rp 3.000 - rp 4500"

splitted_text = text.split()
['di',
'sini',
'saya',
'suka',
'makan',
'nasi',
'bakmoy',
'nya',
'.',
'kroket',
'nya',
'juga',
'enak',
'kok',
'.',
'kisaran',
'harga',
'kroket',
'nya',
'rp',
'3.000',
'-',
'rp',
'4500']
# ic(splitted_text)


text = [word for word in splitted_text if word.isalnum()]
ic(text)
['di',
 'sini',
 'saya',
 'suka',
 'makan',
 'nasi',
 'bakmoy',
 'nya',
 'kroket',
 'nya',
 'juga',
 'enak',
 'kok',
 'kisaran',
 'harga',
 'kroket',
 'nya',
 'rp',
 'rp',
 '4500']

# stop word selection

# masking
# leave_1_texts: ['[MASK] sini saya suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di [MASK] saya suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini [MASK] suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya [MASK] makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka [MASK] nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan [MASK] bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi [MASK] nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy [MASK] kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya [MASK] nya juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket [MASK] juga enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya [MASK] enak kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga [MASK] kok kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga enak [MASK] kisaran '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga enak kok [MASK] '
#                     'harga kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     '[MASK] kroket nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga [MASK] nya rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket [MASK] rp rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya [MASK] rp 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp [MASK] 4500',
#                     'di sini saya suka makan nasi bakmoy nya kroket nya juga enak kok kisaran '
#                     'harga kroket nya rp rp [MASK]']


# calculate importance score
# words_perturb: [(11, 'enak', 0.0031429945601217923),
# (3, 'suka', 0.0007801768770754336),
# (14, 'harga', 0.0006359085888476557),
# (9, 'nya', 0.000473365533267156),
# (7, 'nya', 0.0003898470298651091),
# (16, 'nya', 0.00012333721835844358),
# (13, 'kisaran', 3.606211047113561e-05),
# (5, 'nasi', 1.6093513082182653e-05),
# (4, 'makan', -2.4735315715673778e-05),
# (15, 'kroket', -0.00010090048064270718),
# (18, 'rp', -0.0001560206099924244),
# (17, 'rp', -0.00019165179310220992),
# (6, 'bakmoy', -0.0002272208577345225),
# (8, 'kroket', -0.0002860800109338868),
# (19, '4500', -0.0003094311134042016)]


# perturbation ratio
# ic| top_words_perturb: [(11, 'enak', 0.0031429945601217923),
#                         (3, 'suka', 0.0007801768770754336),
#                         (14, 'harga', 0.0006359085888476557),
#                         (9, 'nya', 0.000473365533267156),
#                         (7, 'nya', 0.0003898470298651091),
#                         (16, 'nya', 0.00012333721835844358)]



# codemixing
# {'enak': 'nice', 
# 'suka': 'like', 
# 'harga': 'price', 
# 'nya': 'his', 
# 'kroket': 'croquette', 
# 'kisaran': 'range', 
# 'nasi': 'rice', 
# 'makan': 'eat', 
# 'bakmoy': 'noodles'}	

# see if has enough semantic similarity score
# ic| first_perturbation_sim_score: 0.98318493

# return

# %%
path = ("./data/emot-emotion-twitter/train_preprocess.csv")
LABEL2INDEX_EMOT = {'sadness': 0, 'anger': 1, 'love': 2, 'fear': 3, 'happy': 4}

emot_train = pd.read_csv("./data/emot-emotion-twitter/train_preprocess.csv")
emot_valid = pd.read_csv("./data/emot-emotion-twitter/valid_preprocess.csv")

emot_train['label'] = emot_train['label'].apply(lambda sen: LABEL2INDEX_EMOT[sen])



LABEL2INDEX_SMSA = {'positive': 0, 'neutral': 1, 'negative': 2}

smsa_train = pd.read_csv("./data/smsa-document-sentiment/train_preprocess.tsv", sep='\t', header=None)
smsa_train.columns = ['text','sentiment']
smsa_train['sentiment'] = smsa_train['sentiment'].apply(lambda lab: LABEL2INDEX_SMSA[lab])

smsa_valid = pd.read_csv("./data/smsa-document-sentiment/valid_preprocess.tsv", sep='\t', header=None)
smsa_valid.columns = ['text','sentiment']
smsa_valid['sentiment'] = smsa_valid['sentiment'].apply(lambda lab: LABEL2INDEX_SMSA[lab])

# %%
# display(emot_train.head())
# display(emot_valid.head())

# display(smsa_train.head())
# display(smsa_valid.head())

# %%
def file_reader(path):
    a_file = open(path, "r")


    vocab = []

    for line in a_file:
        stripped_line = line.strip()

        # line_list = stripped_line.split()

        vocab.append(stripped_line)


    a_file.close()
    return set(vocab)
    # print(list_of_lists)

file_reader("./data/smsa-document-sentiment/vocab.txt")

# %%
# smsa_train_vocab = set(smsa_train['text'].str.split(' ').sum())
# smsa_valid_vocab = set(smsa_valid['text'].str.split(' ').sum())

# unique = smsa_train_vocab.union(smsa_valid_vocab)

# print(len(list(sorted(unique))))
