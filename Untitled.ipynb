# %%
import matplotlib.pyplot as axes
import numpy as np
from matplotlib.pyplot import figure
import pandas as pd
# import matplotlib.pyplot as plt
# import matplotlib
from matplotlib.pyplot import figure, xticks

import matplotlib.pyplot as plt
from deep_translator import GoogleTranslator

plt.style.use('ggplot')
# plt.rcParams['axes.facecolor'] = 'white'
pd.set_option('display.max_colwidth', None)
import os

# %%
model_target = "xlmr"
downstream_task = "sentiment"
attack_strategy = "codemixing"
perturbation_technique = "adv"
perturb_ratio = 0.8
dataset = "train"
perturb_lang = "fr"
seed = 26092020

finetune_epoch = 0
if downstream_task == "sentiment":
    finetune_epoch = 5
if downstream_task == "emotion":
    finetune_epoch = 10

exp_name = model_target+"-"+downstream_task+"-"+attack_strategy+"-"+perturb_lang+"-adv"+"-"+str(perturb_ratio)+"-"+dataset
# exp_name = "indobert-emotion-codemixing-en-adv-0.2-train"
print(exp_name)
# Out:
# xlmr-sentiment-codemixing-fr-adv-0.8-train

# %%
df = pd.read_csv(os.getcwd() + r'/result/seed'+str(seed)+"/"+str(dataset)+"/"+str(exp_name)+".csv")
df = df[["perturbed_text", "sentiment"]]

df
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                        perturbed_text  \
# 0      décrochage en bordure de route ini possédé oleh homme d'affaire usine tahu yang sudah douzaines tahun célèbre membuat tahu blanche di Bandung tahu qualité combiné compétence memasak combiné la créativité jadilah décrochage en bordure de route yang menyajikan menu utama fait à partir de tahu ditambah menu umum lain seperti ayam semuanya appétit Indonésie le prix cukup abordable jangan Mademoiselle tahu bletoka le sien tidak perdu dengan yang asli dari domaine
# 1                                                                                                                                                                                                                                                                                                                                                                                    mohon clerc droit dan k212 mmbri preuve faire la fête apa yang harus diwlh agar voix islam tidak
# 2                                                                                                                                                                                                                                                                                            lokasi stratégique di jalan Sumatra Bandung tempat le sien nyaman terutama sofa di étage 2 Paëlla le sien joli sangat en forme dimakan dengan boire Bière du froid apéritif le sien juga
# 3                                                                                                                                                                                                                                                                                                                                                                         comment bahagia le sien diri ini saat déballage emballer dan des biens le sien bon Positionner acheter lagi
# 4                                                                                                                                                                                                                                                                              duh jadi étudiant jangan fier dong amour carte Jaune segala étude dulu yang baik tidak usahlah politique nanti sudah Fini en train d'étudier le sien mau ikut politique juga tidak telat base étudiant
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ...
# 10995                                                                                                                                                                                                                                                                                                                                                                                                                                                                      tidak déçu
# 10996                                                                                                                                                                                                                                                                                                                   enak rasa Cuisiner le sien apalagi Crabe yang agréable kita choisir Crabe le sien sendiri dan masih Frais selalu arrêtez-vous ke sini kalau setiap ke bandung
# 10997                                                                                                                                                                                                                                                                                                                                                                                                                                                   respect yang telah berkoalisi
# 10998                                                                                                                                                                                                                                                                                                                                                                                             Matin Matin di péage pasteur sudah congestionné critique Fabriquer jengkel saja ini
# 10999                                               meskipun sering achats ke yoga di Riau jonction tapi baru pertama temps ini saya voir la vie alimentaire tempat le sien grande dan faire le ménage tidak taudis semacam aire de restauration lainnya dan choix aliments le sien banyak très dari yang traditionnel sampai aliments Ouest ataupun asian mau yang lourd sampai ke yang léger hampir semuanya ada tinggal sélectionner dan disesuaikan sama biaya makan le sien saja
#
#        sentiment
# 0              0
# 1              1
# 2              0
# 3              0
# 4              2
# ...          ...
# 10995          0
# 10996          0
# 10997          1
# 10998          2
# 10999          0
#
# [11000 rows x 2 columns]

# %%
import pandas as pd
import os
from icecream import ic

dataset = "valid"

path_train = str(os.getcwd()) + "/result/seed" + str(seed) + "/" + "train" + "/"
path_valid = str(os.getcwd()) + "/result/seed" + str(seed) + "/" + "valid" + "/"

dir_list_train = os.listdir(path_train)
dir_list_valid = os.listdir(path_valid)


dir_list
# Out:
# ['indobertlarge-sentiment-codemixing-it-adv-0.8-valid.csv',
#  'indobert-emotion-codemixing-it-adv-0.6-valid.csv',
#  'indobertlarge-emotion-codemixing-en-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-sr-adv-0.4-valid.csv',
#  'mbert-sentiment-sr-adv-0.2-valid.csv',
#  'indobert-sentiment-codemixing-ms-adv-0.2-valid.csv',
#  'indobert-emotion-codemixing-su-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-sr-adv-0.2-valid.csv',
#  'xlmrlarge-emotion-codemixing-ms-adv-0.2-valid.csv',
#  'indobertlarge-sentiment-codemixing-en-adv-0.2-valid.csv',
#  'mbert-sentiment-codemixing-su-adv-0.8-valid.csv',
#  'xlmrlarge-sentiment-codemixing-fr-adv-0.4-valid.csv',
#  'mbert-sentiment-codemixing-fr-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-en-adv-0.6-valid.csv',
#  'mbert-sentiment-codemixing-su-adv-0.4-valid.csv',
#  'indobertlarge-sentiment-codemixing-ms-adv-0.2-valid.csv',
#  'xlmrlarge-sentiment-sr-adv-0.6-valid.csv',
#  'xlmrlarge-emotion-codemixing-su-adv-0.6-valid.csv',
#  'mbert-sentiment-codemixing-it-adv-0.4-valid.csv',
#  'indobertlarge-sentiment-codemixing-jw-adv-0.4-valid.csv',
#  'indobert-sentiment-codemixing-fr-adv-0.6-valid.csv',
#  'xlmr-emotion-codemixing-it-adv-0.6-valid.csv',
#  'indobertlarge-emotion-codemixing-ms-adv-0.4-valid.csv',
#  'indobertlarge-emotion-codemixing-fr-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-codemixing-en-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-it-adv-0.6-valid.csv',
#  'mbert-sentiment-codemixing-en-adv-0.4-valid.csv',
#  'indobert-emotion-sr-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-sr-adv-0.4-valid.csv',
#  'xlmr-emotion-codemixing-jw-adv-0.8-valid.csv',
#  'xlmrlarge-sentiment-codemixing-en-adv-0.2-valid.csv',
#  'indobertlarge-sentiment-codemixing-ms-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-it-adv-0.2-valid.csv',
#  'indobert-sentiment-codemixing-it-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-jw-adv-0.8-valid.csv',
#  'mbert-emotion-codemixing-en-adv-0.8-valid.csv',
#  'mbert-sentiment-codemixing-su-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-ms-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-codemixing-it-adv-0.2-valid.csv',
#  'indobert-emotion-codemixing-en-adv-0.8-valid.csv',
#  'mbert-sentiment-codemixing-fr-adv-0.4-valid.csv',
#  'indobertlarge-sentiment-codemixing-jw-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-ms-adv-0.4-valid.csv',
#  'xlmr-emotion-sr-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-jw-adv-0.4-valid.csv',
#  'indobertlarge-sentiment-codemixing-ms-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-su-adv-0.8-valid.csv',
#  'xlmrlarge-sentiment-sr-adv-0.2-valid.csv',
#  'indobertlarge-sentiment-codemixing-jw-adv-0.2-valid.csv',
#  'mbert-sentiment-codemixing-jw-adv-0.4-valid.csv',
#  'indobertlarge-emotion-sr-adv-0.4-valid.csv',
#  'indobert-emotion-codemixing-fr-adv-0.2-valid.csv',
#  'xlmr-emotion-codemixing-jw-adv-0.6-valid.csv',
#  'indobert-emotion-codemixing-en-adv-0.4-valid.csv',
#  'indobertlarge-sentiment-codemixing-su-adv-0.8-valid.csv',
#  'xlmrlarge-sentiment-codemixing-fr-adv-0.8-valid.csv',
#  'xlmr-sentiment-sr-adv-0.8-valid.csv',
#  'xlmrlarge-sentiment-codemixing-su-adv-0.6-valid.csv',
#  'indobert-sentiment-codemixing-en-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-ms-adv-0.6-valid.csv',
#  'xlmr-emotion-sr-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-jw-adv-0.6-valid.csv',
#  'xlmr-sentiment-codemixing-su-adv-0.8-valid.csv',
#  'mbert-sentiment-codemixing-ms-adv-0.8-valid.csv',
#  'mbert-emotion-sr-adv-0.2-valid.csv',
#  'indobert-sentiment-codemixing-su-adv-0.6-valid.csv',
#  'indobertlarge-emotion-codemixing-ms-adv-0.6-valid.csv',
#  'xlmr-sentiment-codemixing-it-adv-0.2-valid.csv',
#  'xlmr-sentiment-codemixing-su-adv-0.6-valid.csv',
#  'indobertlarge-emotion-codemixing-en-adv-0.4-valid.csv',
#  'mbert-sentiment-sr-adv-0.8-valid.csv',
#  'mbert-sentiment-codemixing-it-adv-0.8-valid.csv',
#  'xlmrlarge-emotion-codemixing-jw-adv-0.6-valid.csv',
#  'indobertlarge-sentiment-codemixing-it-adv-0.4-valid.csv',
#  'xlmr-emotion-codemixing-fr-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-su-adv-0.2-valid.csv',
#  'indobert-emotion-codemixing-fr-adv-0.4-valid.csv',
#  'indobert-emotion-sr-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-ms-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-ms-adv-0.4-valid.csv',
#  'indobert-sentiment-codemixing-jw-adv-0.2-valid.csv',
#  'indobertlarge-emotion-codemixing-en-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-ms-adv-0.4-valid.csv',
#  'mbert-sentiment-codemixing-en-adv-0.6-valid.csv',
#  'xlmrlarge-emotion-codemixing-su-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-it-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-ms-adv-0.8-valid.csv',
#  'mbert-emotion-codemixing-fr-adv-0.2-valid.csv',
#  'indobertlarge-sentiment-codemixing-jw-adv-0.6-valid.csv',
#  'xlmrlarge-emotion-codemixing-en-adv-0.8-valid.csv',
#  'xlmrlarge-emotion-codemixing-ms-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-it-adv-0.8-valid.csv',
#  'mbert-sentiment-codemixing-su-adv-0.2-valid.csv',
#  'indobertlarge-emotion-codemixing-ms-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-fr-adv-0.8-valid.csv',
#  'indobertlarge-emotion-codemixing-it-adv-0.4-valid.csv',
#  'indobert-sentiment-codemixing-en-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-ms-adv-0.2-valid.csv',
#  'xlmr-sentiment-sr-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-it-adv-0.8-valid.csv',
#  'mbert-sentiment-codemixing-ms-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-fr-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-su-adv-0.2-valid.csv',
#  'mbert-emotion-sr-adv-0.6-valid.csv',
#  'mbert-sentiment-codemixing-ms-adv-0.6-valid.csv',
#  'indobert-sentiment-codemixing-it-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-jw-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-en-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-sr-adv-0.8-valid.csv',
#  'indobert-emotion-codemixing-fr-adv-0.6-valid.csv',
#  'indobert-sentiment-codemixing-en-adv-0.4-valid.csv',
#  'indobert-emotion-codemixing-ms-adv-0.4-valid.csv',
#  'xlmrlarge-sentiment-codemixing-fr-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-en-adv-0.2-valid.csv',
#  'mbert-sentiment-codemixing-jw-adv-0.2-valid.csv',
#  'xlmr-emotion-codemixing-fr-adv-0.2-valid.csv',
#  'indobert-sentiment-codemixing-fr-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-it-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-codemixing-fr-adv-0.4-valid.csv',
#  'indobertlarge-emotion-codemixing-su-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-en-adv-0.4-valid.csv',
#  'indobertlarge-emotion-codemixing-su-adv-0.8-valid.csv',
#  'xlmrlarge-emotion-codemixing-ms-adv-0.6-valid.csv',
#  'mbert-emotion-codemixing-su-adv-0.4-valid.csv',
#  'xlmrlarge-emotion-codemixing-en-adv-0.2-valid.csv',
#  'xlmrlarge-emotion-codemixing-en-adv-0.4-valid.csv',
#  'xlmrlarge-emotion-codemixing-fr-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-jw-adv-0.4-valid.csv',
#  'indobertlarge-emotion-codemixing-fr-adv-0.4-valid.csv',
#  'mbert-sentiment-codemixing-it-adv-0.6-valid.csv',
#  'xlmrlarge-emotion-codemixing-su-adv-0.4-valid.csv',
#  'indobert-sentiment-codemixing-fr-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-jw-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-codemixing-su-adv-0.6-valid.csv',
#  'indobert-sentiment-codemixing-it-adv-0.2-valid.csv',
#  'indobert-emotion-codemixing-jw-adv-0.2-valid.csv',
#  'xlmrlarge-emotion-sr-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-su-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-en-adv-0.4-valid.csv',
#  'xlmrlarge-sentiment-codemixing-jw-adv-0.6-valid.csv',
#  'xlmr-sentiment-codemixing-fr-adv-0.2-valid.csv',
#  'xlmrlarge-emotion-codemixing-su-adv-0.8-valid.csv',
#  'mbert-sentiment-codemixing-en-adv-0.2-valid.csv',
#  'xlmr-emotion-codemixing-fr-adv-0.8-valid.csv',
#  'xlmrlarge-emotion-codemixing-it-adv-0.6-valid.csv',
#  '.ipynb_checkpoints',
#  'xlmr-emotion-codemixing-ms-adv-0.2-valid.csv',
#  'indobert-sentiment-codemixing-fr-adv-0.2-valid.csv',
#  'indobertlarge-sentiment-codemixing-en-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-su-adv-0.6-valid.csv',
#  'indobert-emotion-codemixing-ms-adv-0.8-valid.csv',
#  'mbert-sentiment-codemixing-en-adv-0.8-valid.csv',
#  'indobert-emotion-codemixing-en-adv-0.6-valid.csv',
#  'xlmr-emotion-sr-adv-0.4-valid.csv',
#  'indobertlarge-emotion-codemixing-jw-adv-0.6-valid.csv',
#  'indobertlarge-emotion-codemixing-it-adv-0.2-valid.csv',
#  'indobert-sentiment-codemixing-ms-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-fr-adv-0.6-valid.csv',
#  'mbert-emotion-sr-adv-0.8-valid.csv',
#  'indobertlarge-emotion-codemixing-it-adv-0.6-valid.csv',
#  'mbert-sentiment-codemixing-fr-adv-0.8-valid.csv',
#  'indobertlarge-emotion-codemixing-su-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-ms-adv-0.2-valid.csv',
#  'indobert-emotion-codemixing-fr-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-su-adv-0.2-valid.csv',
#  'indobertlarge-emotion-codemixing-jw-adv-0.4-valid.csv',
#  'indobert-sentiment-codemixing-su-adv-0.8-valid.csv',
#  'mbert-emotion-codemixing-su-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-codemixing-su-adv-0.2-valid.csv',
#  'indobertlarge-sentiment-codemixing-en-adv-0.6-valid.csv',
#  'mbert-sentiment-codemixing-jw-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-fr-adv-0.4-valid.csv',
#  'xlmrlarge-emotion-codemixing-it-adv-0.2-valid.csv',
#  'xlmrlarge-emotion-sr-adv-0.2-valid.csv',
#  'indobert-sentiment-codemixing-jw-adv-0.4-valid.csv',
#  'mbert-sentiment-codemixing-fr-adv-0.2-valid.csv',
#  'mbert-sentiment-codemixing-jw-adv-0.6-valid.csv',
#  'indobertlarge-sentiment-codemixing-su-adv-0.4-valid.csv',
#  'indobertlarge-emotion-codemixing-ms-adv-0.2-valid.csv',
#  'indobertlarge-emotion-codemixing-su-adv-0.4-valid.csv',
#  'xlmrlarge-emotion-codemixing-ms-adv-0.4-valid.csv',
#  'indobert-sentiment-sr-adv-0.2-valid.csv',
#  'mbert-sentiment-codemixing-ms-adv-0.4-valid.csv',
#  'indobert-sentiment-sr-adv-0.6-valid.csv',
#  'indobertlarge-sentiment-codemixing-fr-adv-0.2-valid.csv',
#  'indobertlarge-sentiment-codemixing-ms-adv-0.6-valid.csv',
#  'indobertlarge-sentiment-sr-adv-0.6-valid.csv',
#  'xlmr-emotion-codemixing-en-adv-0.2-valid.csv',
#  'xlmr-sentiment-codemixing-it-adv-0.6-valid.csv',
#  'indobert-sentiment-codemixing-it-adv-0.6-valid.csv',
#  'xlmrlarge-emotion-codemixing-jw-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-it-adv-0.4-valid.csv',
#  'xlmrlarge-sentiment-codemixing-su-adv-0.4-valid.csv',
#  'xlmrlarge-sentiment-codemixing-su-adv-0.8-valid.csv',
#  'indobert-sentiment-codemixing-su-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-fr-adv-0.8-valid.csv',
#  'indobert-emotion-codemixing-ms-adv-0.6-valid.csv',
#  'indobertlarge-sentiment-codemixing-it-adv-0.6-valid.csv',
#  'mbert-sentiment-sr-adv-0.6-valid.csv',
#  'xlmrlarge-emotion-codemixing-fr-adv-0.2-valid.csv',
#  'indobertlarge-emotion-codemixing-jw-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-it-adv-0.4-valid.csv',
#  'xlmrlarge-emotion-sr-adv-0.6-valid.csv',
#  'indobert-emotion-codemixing-su-adv-0.6-valid.csv',
#  'xlmr-emotion-codemixing-su-adv-0.4-valid.csv',
#  'xlmrlarge-emotion-codemixing-fr-adv-0.4-valid.csv',
#  'indobert-emotion-codemixing-ms-adv-0.2-valid.csv',
#  'indobert-emotion-codemixing-it-adv-0.2-valid.csv',
#  'indobert-sentiment-sr-adv-0.8-valid.csv',
#  'xlmrlarge-emotion-sr-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-jw-adv-0.4-valid.csv',
#  'xlmr-emotion-codemixing-it-adv-0.2-valid.csv',
#  'indobertlarge-emotion-codemixing-fr-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-sr-adv-0.8-valid.csv',
#  'indobert-emotion-sr-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-fr-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-ms-adv-0.6-valid.csv',
#  'indobert-emotion-codemixing-jw-adv-0.8-valid.csv',
#  'indobertlarge-sentiment-codemixing-fr-adv-0.6-valid.csv',
#  'indobert-sentiment-codemixing-jw-adv-0.8-valid.csv',
#  'xlmr-sentiment-sr-adv-0.4-valid.csv',
#  'xlmrlarge-sentiment-codemixing-it-adv-0.6-valid.csv',
#  'indobertlarge-emotion-codemixing-en-adv-0.6-valid.csv',
#  'xlmr-sentiment-codemixing-su-adv-0.4-valid.csv',
#  'xlmr-sentiment-codemixing-en-adv-0.2-valid.csv',
#  'indobert-emotion-codemixing-su-adv-0.2-valid.csv',
#  'xlmr-emotion-sr-adv-0.2-valid.csv',
#  'xlmrlarge-emotion-codemixing-jw-adv-0.8-valid.csv',
#  'indobertlarge-emotion-sr-adv-0.6-valid.csv',
#  'indobert-emotion-codemixing-jw-adv-0.6-valid.csv',
#  'indobertlarge-emotion-sr-adv-0.2-valid.csv',
#  'mbert-emotion-sr-adv-0.4-valid.csv',
#  'indobert-emotion-codemixing-su-adv-0.4-valid.csv',
#  'xlmrlarge-sentiment-codemixing-it-adv-0.4-valid.csv',
#  'xlmr-sentiment-codemixing-en-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-ms-adv-0.6-valid.csv',
#  'mbert-emotion-codemixing-ms-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-en-adv-0.4-valid.csv',
#  'indobert-sentiment-sr-adv-0.4-valid.csv',
#  'indobert-sentiment-codemixing-ms-adv-0.4-valid.csv',
#  'indobertlarge-sentiment-codemixing-fr-adv-0.8-valid.csv',
#  'indobert-emotion-sr-adv-0.2-valid.csv',
#  'xlmrlarge-emotion-codemixing-en-adv-0.6-valid.csv',
#  'xlmrlarge-sentiment-codemixing-jw-adv-0.8-valid.csv',
#  'indobertlarge-emotion-sr-adv-0.8-valid.csv',
#  'indobert-emotion-codemixing-jw-adv-0.4-valid.csv',
#  'xlmr-sentiment-codemixing-fr-adv-0.6-valid.csv',
#  'xlmr-sentiment-sr-adv-0.2-valid.csv',
#  'mbert-emotion-codemixing-su-adv-0.6-valid.csv',
#  'indobert-sentiment-codemixing-jw-adv-0.6-valid.csv',
#  'mbert-emotion-codemixing-en-adv-0.6-valid.csv',
#  'xlmr-emotion-codemixing-fr-adv-0.4-valid.csv',
#  'xlmr-sentiment-codemixing-it-adv-0.4-valid.csv',
#  'xlmrlarge-sentiment-codemixing-jw-adv-0.2-valid.csv',
#  'xlmr-emotion-codemixing-en-adv-0.4-valid.csv',
#  'mbert-emotion-codemixing-jw-adv-0.2-valid.csv',
#  'indobertlarge-emotion-codemixing-jw-adv-0.2-valid.csv',
#  'indobert-sentiment-codemixing-en-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-en-adv-0.6-valid.csv',
#  'xlmr-emotion-codemixing-en-adv-0.6-valid.csv',
#  'mbert-sentiment-sr-adv-0.4-valid.csv',
#  'xlmrlarge-emotion-codemixing-fr-adv-0.6-valid.csv',
#  'xlmr-emotion-codemixing-ms-adv-0.6-valid.csv',
#  'indobert-sentiment-codemixing-su-adv-0.4-valid.csv',
#  'mbert-sentiment-codemixing-it-adv-0.2-valid.csv',
#  'xlmrlarge-emotion-codemixing-it-adv-0.4-valid.csv',
#  'indobert-emotion-codemixing-it-adv-0.4-valid.csv',
#  'xlmrlarge-emotion-codemixing-it-adv-0.8-valid.csv',
#  'indobert-emotion-codemixing-en-adv-0.2-valid.csv',
#  'indobertlarge-emotion-codemixing-it-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-jw-adv-0.4-valid.csv',
#  'indobertlarge-emotion-codemixing-fr-adv-0.2-valid.csv',
#  'indobert-emotion-codemixing-it-adv-0.8-valid.csv',
#  'xlmrlarge-emotion-codemixing-jw-adv-0.2-valid.csv',
#  'xlmr-sentiment-codemixing-ms-adv-0.2-valid.csv',
#  'xlmrlarge-sentiment-codemixing-ms-adv-0.4-valid.csv',
#  'indobert-sentiment-codemixing-ms-adv-0.8-valid.csv',
#  'xlmr-sentiment-codemixing-jw-adv-0.2-valid.csv',
#  'xlmrlarge-sentiment-codemixing-it-adv-0.2-valid.csv',
#  'xlmr-emotion-codemixing-en-adv-0.8-valid.csv',
#  'xlmr-emotion-codemixing-jw-adv-0.2-valid.csv']
